# %%
import os
import numpy as np
import mne

# %% [markdown]
# ### Loading and Preprocessing the PhysioNet Motor Imagery Dataset
# 1. Set the dataset path - where the edf files are stored (edf files are the data eeg)
# 2. Select run - we use motor imagery runs (left hand imagery vs right hand imagery)
# 3. Load Edf files with mne - reads eeg signlas for each subject and run
# 4. Extract events - they will be out labels for classification
# 5. Epoching - segment the continuous eeg into short trials
# 6. Stroe trials and labels
#
# ### This is when both feet and both fists are moved

# %%
dataset_root = "/media/sparsh/CaptainSlow/Programming Stuff/Programming Stuff/Code _n_ Stuff/All Projects/All Projects/PhysioNet EEG Motor Movement/eeg_motor_movement_dataset"


X_all = []
y_all = []
expected_time_len = None
runs_to_use = ['R04', 'R08', 'R12']  # Runs: motor imagery (hands vs feet)

for subject_folder in sorted(os.listdir(dataset_root)):
    subject_path = os.path.join(dataset_root, subject_folder)
    if not os.path.isdir(subject_path):
        continue

    for run in runs_to_use:
        r_file = os.path.join(subject_path, f"{subject_folder}{run}.edf")
        if not os.path.exists(r_file):
            print(f"File not found: {r_file}")
            continue

        try:
            raw = mne.io.read_raw_edf(r_file, preload=True, verbose=False)
            # raw.filter(7., 30., fir_design='firwin', verbose=False)
            # raw.set_eeg_reference('average', verbose=False)
            # ica = mne.preprocessing.ICA(verbose=False, n_components=20, max_iter = 'auto')
            # ica.fit(raw)



            events, event_id = mne.events_from_annotations(raw, verbose=False)

            if 'T1' not in event_id or 'T2' not in event_id:
                print(f"⚠️ Skipping {r_file}, missing T1/T2 events")
                continue

            selected_events = {'left': event_id['T1'], 'right': event_id['T2']}
            epochs = mne.Epochs(raw, events,event_id=selected_events, tmin=0.5, tmax=2.5,baseline=None,preload=True,verbose=False)

            X = epochs.get_data()  # shape: (n_trials, n_channels, n_times)
            y = epochs.events[:, -1] - min(epochs.events[:, -1])  # 0 for left, 1 for right

            print(f"{subject_folder}-{run}: epochs {X.shape}, labels {np.bincount(y)}")

            if expected_time_len is None:
                expected_time_len = X.shape[2]
            if X.shape[2] != expected_time_len:
                print(f"Skipping {subject_folder}-{run}, time length mismatch")
                continue

            X_all.append(X)
            y_all.append(y)

        except Exception as e:
            print(f"Error loading {r_file}: {e}")


if len(X_all) == 0:
    raise ValueError("No data loaded. Check dataset path or preprocessing.")

X_all = np.vstack(X_all)
y_all = np.hstack(y_all)

print("Data Loaded Successfully!")
print("Data shape:", X_all.shape)
print("Labels distribution:", np.bincount(y_all))
# Out:
# S001-R04: epochs (15, 64, 321), labels [8 7]
# S001-R08: epochs (15, 64, 321), labels [8 7]
# S001-R12: epochs (15, 64, 321), labels [7 8]
# S002-R04: epochs (15, 64, 321), labels [7 8]
# S002-R08: epochs (15, 64, 321), labels [8 7]
# S002-R12: epochs (15, 64, 321), labels [8 7]
# S003-R04: epochs (15, 64, 321), labels [8 7]
# S003-R08: epochs (15, 64, 321), labels [7 8]
# S003-R12: epochs (15, 64, 321), labels [8 7]
# S004-R04: epochs (15, 64, 321), labels [8 7]
# S004-R08: epochs (15, 64, 321), labels [7 8]
# S004-R12: epochs (15, 64, 321), labels [8 7]
# S005-R04: epochs (15, 64, 321), labels [7 8]
# S005-R08: epochs (15, 64, 321), labels [7 8]
# S005-R12: epochs (15, 64, 321), labels [7 8]
# S006-R04: epochs (15, 64, 321), labels [8 7]
# S006-R08: epochs (15, 64, 321), labels [8 7]
# S006-R12: epochs (15, 64, 321), labels [8 7]
# S007-R04: epochs (15, 64, 321), labels [8 7]
# S007-R08: epochs (15, 64, 321), labels [8 7]
# S007-R12: epochs (15, 64, 321), labels [7 8]
# S008-R04: epochs (15, 64, 321), labels [7 8]
# S008-R08: epochs (15, 64, 321), labels [7 8]
# S008-R12: epochs (15, 64, 321), labels [8 7]
# S009-R04: epochs (15, 64, 321), labels [8 7]
# S009-R08: epochs (15, 64, 321), labels [8 7]
# S009-R12: epochs (15, 64, 321), labels [8 7]
# S010-R04: epochs (15, 64, 321), labels [8 7]
# S010-R08: epochs (15, 64, 321), labels [8 7]
# S010-R12: epochs (15, 64, 321), labels [8 7]
# S011-R04: epochs (15, 64, 321), labels [8 7]
# S011-R08: epochs (15, 64, 321), labels [7 8]
# S011-R12: epochs (15, 64, 321), labels [8 7]
# S012-R04: epochs (15, 64, 321), labels [7 8]
# S012-R08: epochs (15, 64, 321), labels [7 8]
# S012-R12: epochs (15, 64, 321), labels [7 8]
# S013-R04: epochs (15, 64, 321), labels [8 7]
# S013-R08: epochs (15, 64, 321), labels [8 7]
# S013-R12: epochs (15, 64, 321), labels [7 8]
# S014-R04: epochs (15, 64, 321), labels [7 8]
# S014-R08: epochs (15, 64, 321), labels [7 8]
# S014-R12: epochs (15, 64, 321), labels [8 7]
# S015-R04: epochs (15, 64, 321), labels [7 8]
# S015-R08: epochs (15, 64, 321), labels [8 7]
# S015-R12: epochs (15, 64, 321), labels [8 7]
# S016-R04: epochs (15, 64, 321), labels [7 8]
# S016-R08: epochs (15, 64, 321), labels [8 7]
# S016-R12: epochs (15, 64, 321), labels [7 8]
# S017-R04: epochs (15, 64, 321), labels [7 8]
# S017-R08: epochs (15, 64, 321), labels [8 7]
# S017-R12: epochs (15, 64, 321), labels [8 7]
# S018-R04: epochs (15, 64, 321), labels [7 8]
# S018-R08: epochs (15, 64, 321), labels [8 7]
# S018-R12: epochs (15, 64, 321), labels [7 8]
# S019-R04: epochs (15, 64, 321), labels [8 7]
# S019-R08: epochs (15, 64, 321), labels [8 7]
# S019-R12: epochs (15, 64, 321), labels [7 8]
# S020-R04: epochs (15, 64, 321), labels [7 8]
# S020-R08: epochs (15, 64, 321), labels [8 7]
# S020-R12: epochs (15, 64, 321), labels [8 7]
# S021-R04: epochs (15, 64, 321), labels [8 7]
# S021-R08: epochs (15, 64, 321), labels [8 7]
# S021-R12: epochs (15, 64, 321), labels [8 7]
# S022-R04: epochs (15, 64, 321), labels [7 8]
# S022-R08: epochs (15, 64, 321), labels [8 7]
# S022-R12: epochs (15, 64, 321), labels [7 8]
# S023-R04: epochs (15, 64, 321), labels [8 7]
# S023-R08: epochs (15, 64, 321), labels [7 8]
# S023-R12: epochs (15, 64, 321), labels [7 8]
# S024-R04: epochs (15, 64, 321), labels [7 8]
# S024-R08: epochs (15, 64, 321), labels [7 8]
# S024-R12: epochs (15, 64, 321), labels [8 7]
# S025-R04: epochs (15, 64, 321), labels [7 8]
# S025-R08: epochs (15, 64, 321), labels [7 8]
# S025-R12: epochs (15, 64, 321), labels [8 7]
# S026-R04: epochs (15, 64, 321), labels [8 7]
# S026-R08: epochs (15, 64, 321), labels [8 7]
# S026-R12: epochs (15, 64, 321), labels [8 7]
# S027-R04: epochs (15, 64, 321), labels [8 7]
# S027-R08: epochs (15, 64, 321), labels [7 8]
# S027-R12: epochs (15, 64, 321), labels [8 7]
# S028-R04: epochs (15, 64, 321), labels [8 7]
# S028-R08: epochs (15, 64, 321), labels [7 8]
# S028-R12: epochs (15, 64, 321), labels [7 8]
# S029-R04: epochs (15, 64, 321), labels [8 7]
# S029-R08: epochs (15, 64, 321), labels [8 7]
# S029-R12: epochs (15, 64, 321), labels [7 8]
# S030-R04: epochs (15, 64, 321), labels [8 7]
# S030-R08: epochs (15, 64, 321), labels [8 7]
# S030-R12: epochs (15, 64, 321), labels [8 7]
# S031-R04: epochs (15, 64, 321), labels [8 7]
# S031-R08: epochs (15, 64, 321), labels [7 8]
# S031-R12: epochs (15, 64, 321), labels [7 8]
# S032-R04: epochs (15, 64, 321), labels [7 8]
# S032-R08: epochs (15, 64, 321), labels [7 8]
# S032-R12: epochs (15, 64, 321), labels [7 8]
# S033-R04: epochs (15, 64, 321), labels [8 7]
# S033-R08: epochs (15, 64, 321), labels [8 7]
# S033-R12: epochs (15, 64, 321), labels [7 8]
# S034-R04: epochs (15, 64, 321), labels [7 8]
# S034-R08: epochs (15, 64, 321), labels [7 8]
# S034-R12: epochs (15, 64, 321), labels [7 8]
# S035-R04: epochs (15, 64, 321), labels [8 7]
# S035-R08: epochs (15, 64, 321), labels [7 8]
# S035-R12: epochs (15, 64, 321), labels [7 8]
# S036-R04: epochs (15, 64, 321), labels [8 7]
# S036-R08: epochs (15, 64, 321), labels [7 8]
# S036-R12: epochs (15, 64, 321), labels [8 7]
# S037-R04: epochs (15, 64, 321), labels [8 7]
# S037-R08: epochs (15, 64, 321), labels [8 7]
# S037-R12: epochs (15, 64, 321), labels [7 8]
# S038-R04: epochs (15, 64, 321), labels [8 7]
# S038-R08: epochs (15, 64, 321), labels [8 7]
# S038-R12: epochs (15, 64, 321), labels [7 8]
# S039-R04: epochs (15, 64, 321), labels [8 7]
# S039-R08: epochs (15, 64, 321), labels [8 7]
# S039-R12: epochs (15, 64, 321), labels [7 8]
# S040-R04: epochs (15, 64, 321), labels [7 8]
# S040-R08: epochs (15, 64, 321), labels [7 8]
# S040-R12: epochs (15, 64, 321), labels [7 8]
# S041-R04: epochs (15, 64, 321), labels [8 7]
# S041-R08: epochs (15, 64, 321), labels [8 7]
# S041-R12: epochs (15, 64, 321), labels [8 7]
# S042-R04: epochs (15, 64, 321), labels [7 8]
# S042-R08: epochs (15, 64, 321), labels [8 7]
# S042-R12: epochs (15, 64, 321), labels [7 8]
# S043-R04: epochs (15, 64, 321), labels [8 7]
# S043-R08: epochs (15, 64, 321), labels [7 8]
# S043-R12: epochs (15, 64, 321), labels [8 7]
# S044-R04: epochs (15, 64, 321), labels [7 8]
# S044-R08: epochs (15, 64, 321), labels [7 8]
# S044-R12: epochs (15, 64, 321), labels [8 7]
# S045-R04: epochs (15, 64, 321), labels [8 7]
# S045-R08: epochs (15, 64, 321), labels [8 7]
# S045-R12: epochs (15, 64, 321), labels [7 8]
# S046-R04: epochs (15, 64, 321), labels [8 7]
# S046-R08: epochs (15, 64, 321), labels [7 8]
# S046-R12: epochs (15, 64, 321), labels [8 7]
# S047-R04: epochs (15, 64, 321), labels [8 7]
# S047-R08: epochs (15, 64, 321), labels [8 7]
# S047-R12: epochs (15, 64, 321), labels [8 7]
# S048-R04: epochs (15, 64, 321), labels [8 7]
# S048-R08: epochs (15, 64, 321), labels [7 8]
# S048-R12: epochs (15, 64, 321), labels [7 8]
# S049-R04: epochs (15, 64, 321), labels [7 8]
# S049-R08: epochs (15, 64, 321), labels [8 7]
# S049-R12: epochs (15, 64, 321), labels [8 7]
# S050-R04: epochs (15, 64, 321), labels [7 8]
# S050-R08: epochs (15, 64, 321), labels [8 7]
# S050-R12: epochs (15, 64, 321), labels [8 7]
# S051-R04: epochs (15, 64, 321), labels [8 7]
# S051-R08: epochs (15, 64, 321), labels [8 7]
# S051-R12: epochs (15, 64, 321), labels [8 7]
# S052-R04: epochs (15, 64, 321), labels [8 7]
# S052-R08: epochs (15, 64, 321), labels [8 7]
# S052-R12: epochs (15, 64, 321), labels [8 7]
# S053-R04: epochs (15, 64, 321), labels [7 8]
# S053-R08: epochs (15, 64, 321), labels [7 8]
# S053-R12: epochs (15, 64, 321), labels [8 7]
# S054-R04: epochs (15, 64, 321), labels [8 7]
# S054-R08: epochs (15, 64, 321), labels [7 8]
# S054-R12: epochs (15, 64, 321), labels [8 7]
# S055-R04: epochs (15, 64, 321), labels [8 7]
# S055-R08: epochs (15, 64, 321), labels [8 7]
# S055-R12: epochs (15, 64, 321), labels [7 8]
# S056-R04: epochs (15, 64, 321), labels [7 8]
# S056-R08: epochs (15, 64, 321), labels [7 8]
# S056-R12: epochs (15, 64, 321), labels [8 7]
# S057-R04: epochs (15, 64, 321), labels [8 7]
# S057-R08: epochs (15, 64, 321), labels [8 7]
# S057-R12: epochs (15, 64, 321), labels [8 7]
# S058-R04: epochs (15, 64, 321), labels [8 7]
# S058-R08: epochs (15, 64, 321), labels [8 7]
# S058-R12: epochs (15, 64, 321), labels [8 7]
# S059-R04: epochs (15, 64, 321), labels [8 7]
# S059-R08: epochs (15, 64, 321), labels [8 7]
# S059-R12: epochs (15, 64, 321), labels [8 7]
# S060-R04: epochs (15, 64, 321), labels [7 8]
# S060-R08: epochs (15, 64, 321), labels [8 7]
# S060-R12: epochs (15, 64, 321), labels [8 7]
# S061-R04: epochs (15, 64, 321), labels [7 8]
# S061-R08: epochs (15, 64, 321), labels [8 7]
# S061-R12: epochs (15, 64, 321), labels [7 8]
# S062-R04: epochs (15, 64, 321), labels [7 8]
# S062-R08: epochs (15, 64, 321), labels [8 7]
# S062-R12: epochs (15, 64, 321), labels [8 7]
# S063-R04: epochs (15, 64, 321), labels [7 8]
# S063-R08: epochs (15, 64, 321), labels [7 8]
# S063-R12: epochs (15, 64, 321), labels [8 7]
# S064-R04: epochs (15, 64, 321), labels [8 7]
# S064-R08: epochs (15, 64, 321), labels [8 7]
# S064-R12: epochs (15, 64, 321), labels [7 8]
# S065-R04: epochs (15, 64, 321), labels [8 7]
# S065-R08: epochs (15, 64, 321), labels [8 7]
# S065-R12: epochs (15, 64, 321), labels [8 7]
# S066-R04: epochs (15, 64, 321), labels [7 8]
# S066-R08: epochs (15, 64, 321), labels [8 7]
# S066-R12: epochs (15, 64, 321), labels [7 8]
# S067-R04: epochs (15, 64, 321), labels [8 7]
# S067-R08: epochs (15, 64, 321), labels [7 8]
# S067-R12: epochs (15, 64, 321), labels [7 8]
# S068-R04: epochs (15, 64, 321), labels [8 7]
# S068-R08: epochs (15, 64, 321), labels [7 8]
# S068-R12: epochs (15, 64, 321), labels [7 8]
# S069-R04: epochs (15, 64, 321), labels [8 7]
# S069-R08: epochs (15, 64, 321), labels [8 7]
# S069-R12: epochs (15, 64, 321), labels [8 7]
# S070-R04: epochs (15, 64, 321), labels [7 8]
# S070-R08: epochs (15, 64, 321), labels [8 7]
# S070-R12: epochs (15, 64, 321), labels [7 8]
# S071-R04: epochs (15, 64, 321), labels [8 7]
# S071-R08: epochs (15, 64, 321), labels [7 8]
# S071-R12: epochs (15, 64, 321), labels [7 8]
# S072-R04: epochs (15, 64, 321), labels [7 8]
# S072-R08: epochs (15, 64, 321), labels [7 8]
# S072-R12: epochs (15, 64, 321), labels [8 7]
# S073-R04: epochs (15, 64, 321), labels [8 7]
# S073-R08: epochs (15, 64, 321), labels [8 7]
# S073-R12: epochs (15, 64, 321), labels [7 8]
# S074-R04: epochs (15, 64, 321), labels [8 7]
# S074-R08: epochs (15, 64, 321), labels [8 7]
# S074-R12: epochs (15, 64, 321), labels [8 7]
# S075-R04: epochs (15, 64, 321), labels [7 8]
# S075-R08: epochs (15, 64, 321), labels [7 8]
# S075-R12: epochs (15, 64, 321), labels [8 7]
# S076-R04: epochs (15, 64, 321), labels [8 7]
# S076-R08: epochs (15, 64, 321), labels [8 7]
# S076-R12: epochs (15, 64, 321), labels [7 8]
# S077-R04: epochs (15, 64, 321), labels [7 8]
# S077-R08: epochs (15, 64, 321), labels [7 8]
# S077-R12: epochs (15, 64, 321), labels [7 8]
# S078-R04: epochs (15, 64, 321), labels [8 7]
# S078-R08: epochs (15, 64, 321), labels [7 8]
# S078-R12: epochs (15, 64, 321), labels [8 7]
# S079-R04: epochs (15, 64, 321), labels [8 7]
# S079-R08: epochs (15, 64, 321), labels [7 8]
# S079-R12: epochs (15, 64, 321), labels [7 8]
# S080-R04: epochs (15, 64, 321), labels [7 8]
# S080-R08: epochs (15, 64, 321), labels [8 7]
# S080-R12: epochs (15, 64, 321), labels [8 7]
# S081-R04: epochs (15, 64, 321), labels [7 8]
# S081-R08: epochs (15, 64, 321), labels [7 8]
# S081-R12: epochs (15, 64, 321), labels [8 7]
# S082-R04: epochs (15, 64, 321), labels [8 7]
# S082-R08: epochs (15, 64, 321), labels [7 8]
# S082-R12: epochs (15, 64, 321), labels [8 7]
# S083-R04: epochs (15, 64, 321), labels [8 7]
# S083-R08: epochs (15, 64, 321), labels [7 8]
# S083-R12: epochs (15, 64, 321), labels [7 8]
# S084-R04: epochs (15, 64, 321), labels [8 7]
# S084-R08: epochs (15, 64, 321), labels [8 7]
# S084-R12: epochs (15, 64, 321), labels [7 8]
# S085-R04: epochs (15, 64, 321), labels [8 7]
# S085-R08: epochs (15, 64, 321), labels [8 7]
# S085-R12: epochs (15, 64, 321), labels [7 8]
# S086-R04: epochs (15, 64, 321), labels [8 7]
# S086-R08: epochs (15, 64, 321), labels [7 8]
# S086-R12: epochs (15, 64, 321), labels [7 8]
# S087-R04: epochs (15, 64, 321), labels [8 7]
# S087-R08: epochs (15, 64, 321), labels [7 8]
# S087-R12: epochs (15, 64, 321), labels [7 8]
# S088-R04: epochs (19, 64, 257), labels [10  9]
# Skipping S088-R04, time length mismatch
# S088-R08: epochs (19, 64, 257), labels [10  9]
# Skipping S088-R08, time length mismatch
# S088-R12: epochs (19, 64, 257), labels [ 9 10]
# Skipping S088-R12, time length mismatch
# S089-R04: epochs (15, 64, 321), labels [8 7]
# S089-R08: epochs (15, 64, 321), labels [8 7]
# S089-R12: epochs (15, 64, 321), labels [8 7]
# S090-R04: epochs (15, 64, 321), labels [7 8]
# S090-R08: epochs (15, 64, 321), labels [7 8]
# S090-R12: epochs (15, 64, 321), labels [8 7]
# S091-R04: epochs (15, 64, 321), labels [8 7]
# S091-R08: epochs (15, 64, 321), labels [7 8]
# S091-R12: epochs (15, 64, 321), labels [7 8]
# S092-R04: epochs (19, 64, 257), labels [ 9 10]
# Skipping S092-R04, time length mismatch
# S092-R08: epochs (19, 64, 257), labels [ 9 10]
# Skipping S092-R08, time length mismatch
# S092-R12: epochs (19, 64, 257), labels [ 9 10]
# Skipping S092-R12, time length mismatch
# S093-R04: epochs (15, 64, 321), labels [8 7]
# S093-R08: epochs (15, 64, 321), labels [8 7]
# S093-R12: epochs (15, 64, 321), labels [7 8]
# S094-R04: epochs (15, 64, 321), labels [7 8]
# S094-R08: epochs (15, 64, 321), labels [7 8]
# S094-R12: epochs (15, 64, 321), labels [8 7]
# S095-R04: epochs (15, 64, 321), labels [7 8]
# S095-R08: epochs (15, 64, 321), labels [8 7]
# S095-R12: epochs (15, 64, 321), labels [8 7]
# S096-R04: epochs (15, 64, 321), labels [7 8]
# S096-R08: epochs (15, 64, 321), labels [8 7]
# S096-R12: epochs (15, 64, 321), labels [8 7]
# S097-R04: epochs (15, 64, 321), labels [8 7]
# S097-R08: epochs (15, 64, 321), labels [7 8]
# S097-R12: epochs (15, 64, 321), labels [8 7]
# S098-R04: epochs (15, 64, 321), labels [8 7]
# S098-R08: epochs (15, 64, 321), labels [8 7]
# S098-R12: epochs (15, 64, 321), labels [7 8]
# S099-R04: epochs (15, 64, 321), labels [7 8]
# S099-R08: epochs (15, 64, 321), labels [8 7]
# S099-R12: epochs (15, 64, 321), labels [7 8]
# S100-R04: epochs (12, 64, 257), labels [6 6]
# Skipping S100-R04, time length mismatch
# S100-R08: epochs (12, 64, 257), labels [6 6]
# Skipping S100-R08, time length mismatch
# S100-R12: epochs (12, 64, 257), labels [6 6]
# Skipping S100-R12, time length mismatch
# S101-R04: epochs (15, 64, 321), labels [8 7]
# S101-R08: epochs (15, 64, 321), labels [7 8]
# /tmp/ipykernel_276754/749507165.py:21: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_edf(r_file, preload=True, verbose=False)
# /tmp/ipykernel_276754/749507165.py:21: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_edf(r_file, preload=True, verbose=False)
# /tmp/ipykernel_276754/749507165.py:21: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_edf(r_file, preload=True, verbose=False)
# S101-R12: epochs (15, 64, 321), labels [7 8]
# S102-R04: epochs (15, 64, 321), labels [7 8]
# S102-R08: epochs (15, 64, 321), labels [7 8]
# S102-R12: epochs (15, 64, 321), labels [8 7]
# S103-R04: epochs (15, 64, 321), labels [7 8]
# S103-R08: epochs (15, 64, 321), labels [8 7]
# S103-R12: epochs (15, 64, 321), labels [7 8]
# S104-R04: epochs (15, 64, 321), labels [7 8]
# S104-R08: epochs (13, 64, 321), labels [7 6]
# S104-R12: epochs (15, 64, 321), labels [8 7]
# S105-R04: epochs (15, 64, 321), labels [8 7]
# S105-R08: epochs (15, 64, 321), labels [7 8]
# S105-R12: epochs (15, 64, 321), labels [8 7]
# S106-R04: epochs (15, 64, 321), labels [8 7]
# S106-R08: epochs (15, 64, 321), labels [8 7]
# S106-R12: epochs (15, 64, 321), labels [8 7]
# S107-R04: epochs (15, 64, 321), labels [8 7]
# S107-R08: epochs (15, 64, 321), labels [8 7]
# S107-R12: epochs (15, 64, 321), labels [8 7]
# S108-R04: epochs (15, 64, 321), labels [7 8]
# S108-R08: epochs (15, 64, 321), labels [7 8]
# S108-R12: epochs (15, 64, 321), labels [8 7]
# S109-R04: epochs (15, 64, 321), labels [7 8]
# S109-R08: epochs (15, 64, 321), labels [8 7]
# S109-R12: epochs (15, 64, 321), labels [8 7]
# Data Loaded Successfully!
# Data shape: (4768, 64, 321)
# Labels distribution: [2406 2362]

# %% [markdown]
# ### Labels distribution = [2406 2362]
#
# - 2406 - Label 0 (both fists are moved)
# - 2362 - Label 1 (both feet are moved)

# %% [markdown]
# ### Standardization EEG Data
#
# Raw EEG signals can have very different ranges across channels.
# To make learning stable, we *normalize* each channel by subtracting its mean and dividing by its standard deviation.
#
# This ensures:
# - All channels have values centered around *0*
# - Variations are on a comparable *scale*
# - The neural network can train more effectively

# %%
mean = X_all.mean(axis = (0,2), keepdims = True)
std = X_all.std(axis = (0,2), keepdims = True)
X_all = (X_all - mean) / std

# %% [markdown]
# ### Importing Deep learning dependencies and evaluations metrics
#
# - PyTorch
# - Scikit-Learn

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, random_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ### Data loading and splitting

# %%
# Step 3: Train-test split and DataLoader
import torch
from torch.utils.data import TensorDataset, DataLoader, random_split
import numpy as np

# Convert to PyTorch tensors
X_tensor = torch.tensor(X_all, dtype=torch.float32)
y_tensor = torch.tensor(y_all, dtype=torch.long)

dataset = TensorDataset(X_tensor, y_tensor)

# %% [markdown]
# ### Defining the model
#
# CNN + Random Forest
